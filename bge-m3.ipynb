# %%
import pandas as pd
import numpy as np

# %%
# Load & preprocess data
df=pd.read_excel("Arabic_English_Translation.xlsx")

# %%
df.shape
# Out:
# (48, 3)

# %%
df.columns
# Out:
# Index(['ID', 'Arabic', 'Translation'], dtype='object')

# %%
df
# Out:
#        ID                                             Arabic  \
# 0   105|1  اَلَمۡ تَرَ کَیۡفَ فَعَلَ رَبُّکَ بِاَصۡحٰبِ ا...
# 1   105|2         اَلَمۡ یَجۡعَلۡ کَیۡدَہُمۡ فِیۡ تَضۡلِیۡلٍ
# 2   105|3        وَّ اَرۡسَلَ عَلَیۡہِمۡ طَیۡرًا اَبَابِیۡلَ
# 3   105|4           تَرۡمِیۡہِمۡ بِحِجَارَۃٍ مِّنۡ سِجِّیۡلٍ
# 4   105|5                  فَجَعَلَہُمۡ کَعَصۡفٍ مَّاۡکُوۡلٍ
# 5   106|1                                لِاِیۡلٰفِ قُرَیۡشٍ
# 6   106|2       اٖلٰفِہِمۡ رِحۡلَۃَ الشِّتَآءِ وَ الصَّیۡفِ
# 7   106|3              فَلۡیَعۡبُدُوۡا رَبَّ ہٰذَا الۡبَیۡتِ
# 8   106|4  الَّذِیۡۤ اَطۡعَمَہُمۡ مِّنۡ جُوۡعٍ ۬ ۙ وَّ اٰ...
# 9   107|1          اَرَءَیۡتَ الَّذِیۡ یُکَذِّبُ بِالدِّیۡنِ
# 10  107|2              فَذٰلِکَ الَّذِیۡ یَدُعُّ الۡیَتِیۡمَ
# 11  107|3         وَ لَا یَحُضُّ عَلٰی طَعَامِ الۡمِسۡکِیۡنِ
# 12  107|4                          فَوَیۡلٌ لِّلۡمُصَلِّیۡنَ
# 13  107|5         الَّذِیۡنَ ہُمۡ عَنۡ صَلَاتِہِمۡ سَاہُوۡنَ
# 14  107|6                       الَّذِیۡنَ ہُمۡ یُرَآءُوۡنَ
# 15  107|7                       وَ یَمۡنَعُوۡنَ الۡمَاعُوۡنَ
# 16  108|1                   اِنَّاۤ اَعۡطَیۡنٰکَ الۡکَوۡثَرَ
# 17  108|2                       فَصَلِّ لِرَبِّکَ وَ انۡحَرۡ
# 18  108|3                   اِنَّ شَانِئَکَ ہُوَ الۡاَبۡتَرُ
# 19  109|1                     قُلۡ یٰۤاَیُّہَا الۡکٰفِرُوۡنَ
# 20  109|2                     لَاۤ اَعۡبُدُ مَا تَعۡبُدُوۡنَ
# 21  109|3          وَ لَاۤ اَنۡتُمۡ عٰبِدُوۡنَ مَاۤ اَعۡبُدُ
# 22  109|4             وَ لَاۤ اَنَا عَابِدٌ مَّا عَبَدۡتُّمۡ
# 23  109|5          وَ لَاۤ اَنۡتُمۡ عٰبِدُوۡنَ مَاۤ اَعۡبُدُ
# 24  109|6                    لَکُمۡ دِیۡنُکُمۡ وَلِیَ دِیۡنِ
# 25  110|1           اِذَا جَآءَ نَصۡرُ اللّٰہِ وَ الۡفَتۡحُ
# 26  110|2  وَ رَاَیۡتَ النَّاسَ یَدۡخُلُوۡنَ فِیۡ دِیۡنِ ...
# 27  110|3  فَسَبِّحۡ بِحَمۡدِ رَبِّکَ وَ اسۡتَغۡفِرۡہُ ؕ ...
# 28  111|1             تَبَّتۡ یَدَاۤ اَبِیۡ لَہَبٍ وَّ تَبَّ
# 29  111|2          مَاۤ اَغۡنٰی عَنۡہُ مَالُہٗ وَ مَا کَسَبَ
# 30  111|3                      سَیَصۡلٰی نَارًا ذَاتَ لَہَبٍ
# 31  111|4             وَّ امۡرَاَتُہٗ ؕ حَمَّالَۃَ الۡحَطَبِ
# 32  111|5                فِیۡ جِیۡدِہَا حَبۡلٌ مِّنۡ مَّسَدٍ
# 33  112|1                           قُلۡ ہُوَ اللّٰہُ اَحَدٌ
# 34  112|2                                 اَللّٰہُ الصَّمَدُ
# 35  112|3                   لَمۡ یَلِدۡ ۬ ۙ وَ لَمۡ یُوۡلَدۡ
# 36  112|4                وَ لَمۡ یَکُنۡ لَّہٗ کُفُوًا اَحَدٌ
# 37  113|1                    قُلۡ اَعُوۡذُ بِرَبِّ الۡفَلَقِ
# 38  113|2                              مِنۡ شَرِّ مَا خَلَقَ
# 39  113|3                 وَ مِنۡ شَرِّ غَاسِقٍ اِذَا وَقَبَ
# 40  113|4           وَ مِنۡ شَرِّ النَّفّٰثٰتِ فِی الۡعُقَدِ
# 41  113|5                 وَ مِنۡ شَرِّ حَاسِدٍ اِذَا حَسَدَ
# 42  114|1                     قُلۡ اَعُوۡذُ بِرَبِّ النَّاسِ
# 43  114|2                                    مَلِکِ النَّاسِ
# 44  114|3                                    اِلٰہِ النَّاسِ
# 45  114|4            مِنۡ شَرِّ الۡوَسۡوَاسِ ۬ ۙ الۡخَنَّاسِ
# 46  114|5         الَّذِیۡ یُوَسۡوِسُ فِیۡ صُدُوۡرِ النَّاسِ
# 47  114|6                        مِنَ الۡجِنَّۃِ وَ النَّاسِ
#
#                                           Translation
# 0   Seest thou not how thy Lord dealt with the Com...
# 1   Did He not make their treacherous plan go astray?
# 2          And He sent against them Flights of Birds,
# 3            Striking them with stones of baked clay.
# 4   Then did He make them like an empty field of s...
# 5   For the covenants (of security and safeguard e...
# 6   Their covenants (covering) journeys by winter ...
# 7              Let them adore the Lord of this House,
# 8   Who provides them with food against hunger, an...
# 9   Seest thou one who denies the Judgment (to come)?
# 10  Then such is the (man) who repulses the orphan...
# 11    And encourages not the feeding of the indigent.
# 12                          So woe to the worshippers
# 13               Who are neglectful of their prayers,
# 14          Those who (want but) to be seen (of men),
# 15   But refuse (to supply) (even) neighbourly needs.
# 16  To thee have We granted the Fount (of Abundance).
# 17  Therefore to thy Lord turn in Prayer and Sacri...
# 18  For he who hateth thee, he will be cut off (fr...
# 19                       Say: O ye that reject Faith!
# 20               I worship not that which ye worship,
# 21          Nor will ye worship that which I worship.
# 22  And I will not worship that which ye have been...
# 23          Nor will ye worship that which I worship.
# 24                To you be your Way, and to me mine.
# 25         When comes the Help of Allah, and Victory,
# 26  And thou dost see the people enter Allah's Rel...
# 27  Celebrate the praises of thy Lord, and pray fo...
# 28  Perish the hands of the Father of Flame! Peris...
# 29  No profit to him from all his wealth, and all ...
# 30  Burnt soon will he be in a Fire of Blazing Flame!
# 31  His wife shall carry the (crackling) wood - As...
# 32  A twisted rope of palm-leaf fibre round her (o...
# 33                Say: He is Allah, the One and Only;
# 34                      Allah, the Eternal, Absolute;
# 35              He begetteth not, nor is He begotten;
# 36                   And there is none like unto Him.
# 37       Say: I seek refuge with the Lord of the Dawn
# 38               From the mischief of created things;
# 39   From the mischief of Darkness as it overspreads;
# 40  From the mischief of those who practise secret...
# 41  And from the mischief of the envious one as he...
# 42  Say: I seek refuge with the Lord and Cherisher...
# 43                    The King (or Ruler) of Mankind,
# 44                    The god (or judge) of Mankind,-
# 45  From the mischief of the Whisperer (of Evil), ...
# 46  (The same) who whispers into the hearts of Man...
# 47                         Among Jinns and among men.

# %%
verses = []
texts = []

for idx, row in df.iterrows():
    verse_id = str(row['ID'])
    arabic_text = str(row['Arabic'])
    translation = str(row['Translation'])
    
    # Combine Arabic and English for embedding
    combined_text = f"{arabic_text} {translation}"
    
    verses.append({
        'id': verse_id,
        'arabic': arabic_text,
        'translation': translation,
        'combined_text': combined_text
    })
    texts.append(combined_text)

# %%
texts
# Out:
# ['اَلَمۡ تَرَ کَیۡفَ فَعَلَ رَبُّکَ بِاَصۡحٰبِ الۡفِیۡلِ Seest thou not how thy Lord dealt with the Companions of the Elephant?',
#  'اَلَمۡ یَجۡعَلۡ کَیۡدَہُمۡ فِیۡ تَضۡلِیۡلٍ Did He not make their treacherous plan go astray?',
#  'وَّ اَرۡسَلَ عَلَیۡہِمۡ طَیۡرًا اَبَابِیۡلَ And He sent against them Flights of Birds,',
#  'تَرۡمِیۡہِمۡ بِحِجَارَۃٍ مِّنۡ سِجِّیۡلٍ Striking them with stones of baked clay.',
#  'فَجَعَلَہُمۡ کَعَصۡفٍ مَّاۡکُوۡلٍ Then did He make them like an empty field of stalks and straw, (of which the corn) has been eaten up.',
#  'لِاِیۡلٰفِ قُرَیۡشٍ For the covenants (of security and safeguard enjoyed) by the Quraish,',
#  'اٖلٰفِہِمۡ رِحۡلَۃَ الشِّتَآءِ وَ الصَّیۡفِ Their covenants (covering) journeys by winter and summer,-',
#  'فَلۡیَعۡبُدُوۡا رَبَّ ہٰذَا الۡبَیۡتِ Let them adore the Lord of this House,',
#  'الَّذِیۡۤ اَطۡعَمَہُمۡ مِّنۡ جُوۡعٍ ۬ ۙ وَّ اٰمَنَہُمۡ مِّنۡ خَوۡفٍ Who provides them with food against hunger, and with security against fear (of danger).',
#  'اَرَءَیۡتَ الَّذِیۡ یُکَذِّبُ بِالدِّیۡنِ Seest thou one who denies the Judgment (to come)?',
#  'فَذٰلِکَ الَّذِیۡ یَدُعُّ الۡیَتِیۡمَ Then such is the (man) who repulses the orphan (with harshness),',
#  'وَ لَا یَحُضُّ عَلٰی طَعَامِ الۡمِسۡکِیۡنِ And encourages not the feeding of the indigent.',
#  'فَوَیۡلٌ لِّلۡمُصَلِّیۡنَ So woe to the worshippers',
#  'الَّذِیۡنَ ہُمۡ عَنۡ صَلَاتِہِمۡ سَاہُوۡنَ Who are neglectful of their prayers,',
#  'الَّذِیۡنَ ہُمۡ یُرَآءُوۡنَ Those who (want but) to be seen (of men),',
#  'وَ یَمۡنَعُوۡنَ الۡمَاعُوۡنَ But refuse (to supply) (even) neighbourly needs.',
#  'اِنَّاۤ اَعۡطَیۡنٰکَ الۡکَوۡثَرَ To thee have We granted the Fount (of Abundance).',
#  'فَصَلِّ لِرَبِّکَ وَ انۡحَرۡ Therefore to thy Lord turn in Prayer and Sacrifice.',
#  'اِنَّ شَانِئَکَ ہُوَ الۡاَبۡتَرُ For he who hateth thee, he will be cut off (from Future Hope).',
#  'قُلۡ یٰۤاَیُّہَا الۡکٰفِرُوۡنَ Say: O ye that reject Faith!',
#  'لَاۤ اَعۡبُدُ مَا تَعۡبُدُوۡنَ I worship not that which ye worship,',
#  'وَ لَاۤ اَنۡتُمۡ عٰبِدُوۡنَ مَاۤ اَعۡبُدُ Nor will ye worship that which I worship.',
#  'وَ لَاۤ اَنَا عَابِدٌ مَّا عَبَدۡتُّمۡ And I will not worship that which ye have been wont to worship,',
#  'وَ لَاۤ اَنۡتُمۡ عٰبِدُوۡنَ مَاۤ اَعۡبُدُ Nor will ye worship that which I worship.',
#  'لَکُمۡ دِیۡنُکُمۡ وَلِیَ دِیۡنِ To you be your Way, and to me mine.',
#  'اِذَا جَآءَ نَصۡرُ اللّٰہِ وَ الۡفَتۡحُ When comes the Help of Allah, and Victory,',
#  "وَ رَاَیۡتَ النَّاسَ یَدۡخُلُوۡنَ فِیۡ دِیۡنِ اللّٰہِ اَفۡوَاجًا And thou dost see the people enter Allah's Religion in crowds,",
#  'فَسَبِّحۡ بِحَمۡدِ رَبِّکَ وَ اسۡتَغۡفِرۡہُ ؕ ؔ اِنَّہٗ کَانَ تَوَّابًا Celebrate the praises of thy Lord, and pray for His Forgiveness: For He is Oft-Returning (in Grace and Mercy).',
#  'تَبَّتۡ یَدَاۤ اَبِیۡ لَہَبٍ وَّ تَبَّ Perish the hands of the Father of Flame! Perish he!',
#  'مَاۤ اَغۡنٰی عَنۡہُ مَالُہٗ وَ مَا کَسَبَ No profit to him from all his wealth, and all his gains!',
#  'سَیَصۡلٰی نَارًا ذَاتَ لَہَبٍ Burnt soon will he be in a Fire of Blazing Flame!',
#  'وَّ امۡرَاَتُہٗ ؕ حَمَّالَۃَ الۡحَطَبِ His wife shall carry the (crackling) wood - As fuel!-',
#  'فِیۡ جِیۡدِہَا حَبۡلٌ مِّنۡ مَّسَدٍ A twisted rope of palm-leaf fibre round her (own) neck!',
#  'قُلۡ ہُوَ اللّٰہُ اَحَدٌ Say: He is Allah, the One and Only;',
#  'اَللّٰہُ الصَّمَدُ Allah, the Eternal, Absolute;',
#  'لَمۡ یَلِدۡ ۬ ۙ وَ لَمۡ یُوۡلَدۡ He begetteth not, nor is He begotten;',
#  'وَ لَمۡ یَکُنۡ لَّہٗ کُفُوًا اَحَدٌ And there is none like unto Him.',
#  'قُلۡ اَعُوۡذُ بِرَبِّ الۡفَلَقِ Say: I seek refuge with the Lord of the Dawn',
#  'مِنۡ شَرِّ مَا خَلَقَ From the mischief of created things;',
#  'وَ مِنۡ شَرِّ غَاسِقٍ اِذَا وَقَبَ From the mischief of Darkness as it overspreads;',
#  'وَ مِنۡ شَرِّ النَّفّٰثٰتِ فِی الۡعُقَدِ From the mischief of those who practise secret arts;',
#  'وَ مِنۡ شَرِّ حَاسِدٍ اِذَا حَسَدَ And from the mischief of the envious one as he practises envy.',
#  'قُلۡ اَعُوۡذُ بِرَبِّ النَّاسِ Say: I seek refuge with the Lord and Cherisher of Mankind,',
#  'مَلِکِ النَّاسِ The King (or Ruler) of Mankind,',
#  'اِلٰہِ النَّاسِ The god (or judge) of Mankind,-',
#  'مِنۡ شَرِّ الۡوَسۡوَاسِ ۬ ۙ الۡخَنَّاسِ From the mischief of the Whisperer (of Evil), who withdraws (after his whisper),-',
#  'الَّذِیۡ یُوَسۡوِسُ فِیۡ صُدُوۡرِ النَّاسِ (The same) who whispers into the hearts of Mankind,-',
#  'مِنَ الۡجِنَّۃِ وَ النَّاسِ Among Jinns and among men.']

# %%
from sentence_transformers import SentenceTransformer

# Load a pretrained Sentence Transformer model
model = SentenceTransformer("BAAI/bge-m3")

# %%
model.max_seq_length
# Out:
# 8192

# %%
# Generate Embeddings
embeddings = model.encode(texts, convert_to_numpy=True, normalize_embeddings=True, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Embeddings shape
embeddings.shape
# Out:
# (48, 1024)

# %%
# Data type
embeddings.dtype
# Out:
# dtype('float32')

# %%
import faiss
dimension = embeddings.shape[1]
index = faiss.IndexFlatIP(dimension)
index.add(embeddings)

# %%
# Define Search Function
def search_verses(query, k):
    print(f"Query: '{query}'")
    
    # Generate query embedding
    query_embedding = model.encode([query])
    print(f"Query embedding shape: {query_embedding.shape}")
    
    # Normalize query embedding
    faiss.normalize_L2(query_embedding)
    
    # Search
    scores, indices = index.search(query_embedding.astype(np.float32), k)
    print(f"Found {len(indices[0])} results.")
    
    # Format results
    results = []
    for score, idx in zip(scores[0], indices[0]):
        results.append({
            'score': float(score),
            'id': verses[idx]['id'],
            'arabic': verses[idx]['arabic'],
            'translation': verses[idx]['translation']
        })
    
    return results

# %%
# Test Search
query1 = "What happened to the people of the elephant?"
results1 = search_verses(query1, k=3)
# Out:
# Query: 'What happened to the people of the elephant?'
# Query embedding shape: (1, 1024)
# Found 3 results.

# %%
for i, result in enumerate(results1, 1):
    print(f"Score: {result['score']:.4f}")
    print(f"Verse ID: {result['id']}")
    print(f"Arabic: {result['arabic']}")
    print(f"Translation: {result['translation']}")
# Out:
# Score: 0.5454
# Verse ID: 105|1
# Arabic: اَلَمۡ تَرَ کَیۡفَ فَعَلَ رَبُّکَ بِاَصۡحٰبِ الۡفِیۡلِ
# Translation: Seest thou not how thy Lord dealt with the Companions of the Elephant?
# Score: 0.4465
# Verse ID: 107|4
# Arabic: فَوَیۡلٌ لِّلۡمُصَلِّیۡنَ
# Translation: So woe to the worshippers
# Score: 0.4187
# Verse ID: 105|4
# Arabic: تَرۡمِیۡہِمۡ بِحِجَارَۃٍ مِّنۡ سِجِّیۡلٍ
# Translation: Striking them with stones of baked clay.
